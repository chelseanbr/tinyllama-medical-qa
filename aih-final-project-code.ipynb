# %% [markdown]
# # Fine-Tuning a Large Language Model for Layperson Medical Question Answering
# AI in Healthcare | MSAI Spr '25 | Chelsea Ramos

# %% [markdown]
# - Dataset: MedQuAD
# - Base model: TinyLLaMA

# %%
import json
from pathlib import Path

# Load a few example QA pairs
data_path = Path("MedQuAD/datasets/National_Cancer_Institute/cancer_1.json")
with open(data_path, "r") as f:
    examples = json.load(f)

# Show example
for item in examples[:3]:
    print("Q:", item['question'])
    print("A:", item['answer'])
    print("---")
